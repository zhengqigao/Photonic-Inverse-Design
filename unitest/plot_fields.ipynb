# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
import h5py

# %%
filepath = "../data/fdtd/test_mmi3x3.h5"
with h5py.File(filepath, "r") as hf:
    Ez = hf["Ez"][:]
    eps = hf["eps"][:]

# %%
print(Ez[200].min(), Ez.max())
for i in range(7):
    frame = int(Ez.shape[0]*(15+i*1.25)/41)
    plt.imshow(Ez[frame].transpose(), cmap="RdBu", vmin=-0.25, vmax=0.25)
    plt.savefig(f"../data/fdtd/test_mmi3x3_f{frame}.png", dpi=300)
# Out:
# -0.11993 0.2788
